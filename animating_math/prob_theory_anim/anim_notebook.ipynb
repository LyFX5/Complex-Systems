# %%
import manim as ma

# %%
from scenes import InformationOfRandomVariableGraph, EntropyOfRandomVariableGraph

# %%
ma.config.media_width = "75%"
ma.config.verbosity = "WARNING"

# %%
# %manim -qm InformationOfRandomVariableGraph
# Out:
# Manim Community v0.18.1

# %%
# %manim -qm EntropyOfRandomVariableGraph
# Out:
# Manim Community v0.18.1
